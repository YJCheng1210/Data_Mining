# %% [markdown]
# ## Yahoo News Serach Crawler

# %%
# Import necessary libraries.
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Define the keyword to search.
keyword = 'pelosi'

# %%
# Perform news scraping from Yahoo and extract the result into Pandas dataframe. 
news_data = []
for page in (0,21,41):
    url = 'https://news.search.yahoo.com/search?q={}&b={}'.format(keyword, page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    for news_item in soup.find_all('div', class_='NewsArticle'):
        news_title = news_item.find('h4').text
        news_source = news_item.find('span','s-source').text
        news_description = news_item.find('p','s-desc').text
        news_link = news_item.find('a').get('href')
        news_time = news_item.find('span', class_='fc-2nd').text
        # Perform basic clean text.
        news_time = news_time.replace('·', '').strip()
        news_title = news_title.replace('•', '').strip()
        news_data.append([news_title, news_source, news_description, news_link, news_time])

news_data_df = pd.DataFrame(news_data, columns=['Title','Source','Description','Link','Time'])

# %%
# Display header of dataframe.
news_data_df
# Out:
#                                                 Title  \
# 0   Nancy Pelosi's Taiwan trip has intensified the...
# 1   White House resists Congress’ bipartisan bid t...
# 2   Letters to the Editor: Pelosi's 'megaphone dip...
# 3   Opinion | Speaker Pelosi should bring the priv...
# 4   Chinese diplomat slams Nancy Pelosi over Taiwa...
# 5   Analysis-With Taiwan drills, Xi tries to salva...
# 6   US's Nancy Pelosi arrives in Taiwan's capital ...
# 7   Preston Xanthopoulos: For the 1st time — proba...
# 8   Pelosi: China cannot stop US officials from vi...
# 9   Pelosi Snubs the Media as China Blows up the T...
# 10  Pelosi gives strong backing to Taiwan's democr...
# 11  Pelosi: China cannot stop US officials from vi...
# 12  Pelosi wraps Asia trip leaving Biden, Taiwan, ...
# 13                              Biden Out of the Room
# 14  Pelosi vows China will not isolate Taiwan as m...
# 15     Pelosi to visit Taiwan despite Chinese threats
# 16  Pelosi: US will ‘not allow’ China to isolate T...
# 17  Pelosi portfolio another example why Congress ...
# 18                Pelosi lands in Taiwan amid tension
# 19  Pelosi's Taiwan trip leaves Asian countries ne...
# 20            Pelosi jabs at Xi before leaving Taiwan
# 21  Pelosi vows support to denuclearise N.Korea, p...
# 22  Pelosi's husband pleads not guilty in Californ...
# 23          Pelosi relief rally in Asia - MarketPulse
# 24  Pelosi vows China will not isolate Taiwan as m...
# 25                 Pelosi: US will not abandon Taiwan
# 26  Pelosi meets Taiwan's president, China starts ...
# 27  Pelosi insinúa que las críticas de China por s...
# 28  Pelosi: US will ‘not allow’ China to isolate T...
# 29  Pelosi says US will not abandon Taiwan as Chin...
#
#                               Source  \
# 0                            Fortune
# 1            Politico via Yahoo News
# 2                  Los Angeles Times
# 3                    Washington Post
# 4                           MSN News
# 5             Reuters via Yahoo News
# 6                           MSN News
# 7   Portsmouth Herald via Yahoo News
# 8                 14 WFIE Evansville
# 9                    The Daily Beast
# 10          USA TODAY via Yahoo News
# 11             WBRC Fox 6 Birmingham
# 12                          Newsweek
# 13                       Goshen News
# 14                   Washington Post
# 15           The Week via Yahoo News
# 16           The Hill via Yahoo News
# 17                          Fox News
# 18         Arkansas Democrat-Gazette
# 19                               NPR
# 20                          Politico
# 21                     Investing.com
# 22                          NBC NEWS
# 23                       MarketPulse
# 24                           The Day
# 25                          The Hill
# 26                     Investing.com
# 27                          MSN News
# 28                          The Hill
# 29                  The Boston Globe
#
#                                           Description  \
# 0   This week, U.S. House Speaker Nancy Pelosi bec...
# 1   Speaker Nancy Pelosi's trip to Taipei isn't th...
# 2   To the editor: The problem with megaphone dipl...
# 3   Members from California especially have been r...
# 4   Chinese diplomat slams Nancy Pelosi: ‘Her visi...
